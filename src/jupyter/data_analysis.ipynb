# %%
from pprint import pprint
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy
# %matplotlib inline

# %%
train_data = pd.read_csv('../../data/train.csv')
train_data.head(5)
pprint(train_data.shape)
# Out:
# (1460, 81)

# %%
pprint(train_data.columns)
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
variable_info = pd.read_csv('../../data/variable_info.csv', index_col=0)
for k, v in variable_info.loc[:,['Id','Chinese_notes']].values:
    print("{}: {}".format(k,v))
# Out:
# MSSubClass: 房子的類型（適合怎樣的家庭組成）
# MSZoning: 土地利用情形
# LotFrontage: 連接幾吋街道
# LotArea: 有幾平方英尺
# Street: 鄰近街道的鋪面
# Alley: 房屋外觀（規則或不規則形)
# LotShape: 房屋平坦程度
# LandContour: 房屋鄰近山坡
# Utilities: 公共資源（水電瓦斯污水）
# LotConfig: nan
# LandSlope: 房屋坡度
# Neighborhood: 鄰近著名景點/地標
# Condition1: 附近方便程度（美食、交通、鐵路等）
# Condition2: 附近方便程度（美食、交通、鐵路等）超過一個額外的因素
# BldgType: 房子類型(適合多少人居住）
# HouseStyle: 房子樣式(有無分層）
# OverallQual: 屋況（綜合牆壁狀況等物質方面完善程度）
# OverallCond: 屋況（綜合全部因素含週遭事物）
# YearBuilt: 屋子建造時間
# YearRemodAdd: 屋子改建時間
# RoofStyle: 屋頂樣式
# RoofMatl: 屋頂建材
# E0terior1st: 房屋牆壁的裝潢物質
# E0terior2nd: 房屋牆壁的裝潢物質（若超過一種）
# MasVnrType: 石造裝飾類型
# MasVnrArea: 廣場石造裝飾類型
# E0terQual: 使用建材的品質
# E0terCond: 房屋本身建材的現今狀況
# Foundation: 房屋基礎類型
# BsmtQual: 地下室高度
# BsmtCond: 地下室環境狀況
# BsmtE0posure: 曝曬程度
# BsmtFinType1: 地下室可居住程度
# BsmtFinSF1: 地下室有幾平方英尺
# BsmtFinType2: 地下室可居住程度
# BsmtFinSF2: 地下室有幾平方英尺
# BsmtUnfSF: 未被使用的地下室有幾平方英尺
# TotalBsmtSF: 總地下室面積幾英尺
# Heating: 加熱器類型
# HeatingQC: 加熱器的狀況
# CentralAir: 中央空調
# Electrical: 電力系統
# 1stFlrSF: 一樓面積
# ...

# %%
fig, ax = plt.subplots(1,1,figsize=(7,3), dpi=100)
sns.distplot(train_data.MSSubClass, color='k', kde=False, ax=ax)
